# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
plt.show()

# %%
import pandas as pd

# %%
gdp_oceania = pd.read_csv('data/gapminder_gdp_oceania.csv', index_col='country')

# %%
gdp_oceania
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
years = gdp_oceania.columns.str.replace('gdpPercap_', '')
gdp_oceania.columns = years.astype(int)

# %%
gdp_oceania
# Out:
#                     1952         1957         1962         1967         1972  \
# country
# Australia    10039.59564  10949.64959  12217.22686  14526.12465  16788.62948
# New Zealand  10556.57566  12247.39532  13175.67800  14463.91893  16046.03728
#
#                     1977         1982         1987         1992         1997  \
# country
# Australia    18334.19751  19477.00928  21888.88903  23424.76683  26997.93657
# New Zealand  16233.71770  17632.41040  19007.19129  18363.32494  21050.41377
#
#                     2002         2007
# country
# Australia    30687.75473  34435.36744
# New Zealand  23189.80135  25185.00911

# %%
gdp_oceania.columns
# Out:
# Int64Index([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#             2007],
#            dtype='int64')

# %%
gdp_oceania.loc['Australia'].plot()
plt.xlabel('Year')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
gdp_oceania.T.plot()
plt.ylabel('GDP per capita')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
plt.style.use('ggplot')
gdp_oceania.T.plot(kind = 'bar')
plt.ylabel('GDP per capita')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
plt.plot(time, position)
plt.xlabel('time')
plt.ylabel('position')
# Out:
# Text(0, 0.5, 'position')

# %%
years
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %%
gdp_australia = gdp_oceania.loc['Australia', :]

# %%
plt.plot(years, gdp_australia, 'g--')
plt.xlabel('year')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
gdp_nz = data.loc['New Zealand']

# %%
plt.plot(years, gdp_australia, 'b-', label='Australia')
plt.plot(years, gdp_nz, 'g-', label='New Zealand')
plt.legend(loc='upper left')
plt.xlabel('year')
plt.ylabel('GDP per capital ($)')
# Out:
# Text(0, 0.5, 'GDP per capital ($)')

# %%
plt.scatter(gdp_australia, gdp_nz)
plt.xlabel('GDP per capita, Australia')
plt.ylabel('GDP per capita, NZ')
# Out:
# Text(0, 0.5, 'GDP per capita, NZ')

# %%
gdp_oceania.T.plot.scatter(x = 'Australia', y = 'New Zealand')
# Out:
# <Axes: xlabel='Australia', ylabel='New Zealand'>

# %%
data_europe = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
data_europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data_europe.columns = data_europe.columns.str.replace('gdpPercap_', '').astype(int)

# %%
data_europe.min().plot()
plt.xlabel('year')
plt.ylabel('min GDP per capita')
# Out:
# Text(0, 0.5, 'min GDP per capita')

# %%
data_europe.max().plot()
plt.xlabel('year')
plt.ylabel('max GDP per capital')
# Out:
# Text(0, 0.5, 'max GDP per capital')

# %%
data_asia = pd.read_csv('data/gapminder_gdp_asia.csv', index_col='country')
data_asia
# Out:
#                     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Afghanistan             779.445314      820.853030      853.100710
# Bahrain                9867.084765    11635.799450    12753.275140
# Bangladesh              684.244172      661.637458      686.341554
# Cambodia                368.469286      434.038336      496.913648
# China                   400.448611      575.987001      487.674018
# Hong Kong China        3054.421209     3629.076457     4692.648272
# India                   546.565749      590.061996      658.347151
# Indonesia               749.681655      858.900271      849.289770
# Iran                   3035.326002     3290.257643     4187.329802
# Iraq                   4129.766056     6229.333562     8341.737815
# Israel                 4086.522128     5385.278451     7105.630706
# Japan                  3216.956347     4317.694365     6576.649461
# Jordan                 1546.907807     1886.080591     2348.009158
# ...

# %%
data_asia.describe().T.plot.scatter(x='min', y = 'max')
# !mkdir -p out
plt.savefig('out/gdp_min-vs-max.pdf')

# %%
# !ls -l out
# Out:
# total 28
# -rw-r----- 1 davids users  8224 Apr 26 17:12 gdp_min-vs-max.pdf
# -rw-r----- 1 davids users 13098 Apr 26 17:12 gdp_min-vs-max.png

# %% [markdown]
# ## Python plotting with ggplot syntax

# %%
from plotnine import *

# %%
g = ( ggplot(data_asia.T, aes(x='Afghanistan', y='Bahrain')) +
    geom_point() + theme_classic() )
g
# Out:
# <ggplot: (8764152927425)>

# %%
g.save('out/gdp_afg-vs-bah.pdf')
# Out:
# /home/davids/local/miniconda3/lib/python3.9/site-packages/plotnine/ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /home/davids/local/miniconda3/lib/python3.9/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Filename: out/gdp_afg-vs-bah.pdf
